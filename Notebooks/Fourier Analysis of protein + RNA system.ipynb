# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import rc
plt.rcParams['xtick.labelsize']=20
plt.rcParams['ytick.labelsize']=20
plt.rcParams['legend.fontsize']=20
plt.rcParams['figure.titlesize']=20
plt.rcParams['font.serif'] = 'Garamond'
plt.rcParams['font.family'] = 'serif'

plt.plot([1,2,3],[1,2,3])
plt.xlabel('Gen', fontname = 'Adobe Garamond Pro', fontsize=20)
plt.show()
# Out:
# /home/npradeep96/miniconda3/envs/fipyenv/lib/python2.7/site-packages/matplotlib/font_manager.py:1333: UserWarning: findfont: Font family [u'Adobe Garamond Pro'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.get_fontconfig_fonts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-04a3bc3f9393> in <module>()
# ----> 1 get_fontconfig_fonts()
#
# NameError: name 'get_fontconfig_fonts' is not defined
